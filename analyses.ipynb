# %%
# !pip install pandas
import pandas as pd
# prism file openining 
prism_O00255 = pd.read_csv('/Users/nikola/Desktop/MERGED NEW/prism_O00255.txt', delim_whitespace=True, comment = '#')
prism_O00255
pd.set_option('display.max_columns', None)
prism_O00255.head()

# clean dataset 
# remove stop codons, wild-type 
prism_O00255 = prism_O00255.loc[~(prism_O00255['variant'].str.endswith('=')|prism_O00255['variant'].str.endswith('~')|prism_O00255['variant'].str.endswith('*'))]

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.jointplot(x=prism_O00255["cavity_score_ml_02_00"], y=prism_O00255["esm1b_masked_marginals_01_00"], kind='scatter',marginal_ticks=True)
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
x_threshold = 2
y_threshold = -3
plt.axvline(x_threshold, color='red', linestyle='--', label='X Threshold')
plt.axhline(y_threshold, color='red', linestyle='--', label='Y Threshold')
plt.title ('O00255 = Menin', loc='right', y=-0.01, fontsize = 10)
plt.show()
    
valid_values = ['pathogenic', 'benign']
filtered_df = prism_O00255[prism_O00255["clinvar_Clinvar_signifiance_06_00"].isin(valid_values)]
filtered_df

print(filtered_df[filtered_df["clinvar_Clinvar_signifiance_06_00"]==pathogenic]
 
z =prism_O00255["maxdelta_01"]    
plt.scatter(x=prism_O00255["cavity_score_ml_02_00"], y=prism_O00255["esm1b_masked_marginals_01_00"], c=z,cmap = 'viridis', label = ' Scattetplot')
plt.colorbar(label='Gradient')
cbar.set_label('SpliceAI gradient')
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ('O00255 = MeninO00255 = Menin', loc='right', y=-0.01, fontsize = 10)
plt.show() 

sns.jointplot(x=filtered_df["cavity_score_ml_02_00"], y=filtered_df["esm1b_masked_marginals_01_00"], hue= filtered_df["clinvar_Clinvar_signifiance_06_00"], kind='scatter',marginal_ticks=True, palette={'pathogenic': '#d7191c', 'benign': '#008000'})
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.legend()
plt.title ('O00255 = Menin', loc='right', y=-0.01, fontsize = 10)
 
z =prism_O00255["maxdelta_01"]
x_threshold = 2
y_threshold = -3
plt.axvline(x_threshold, color='red', linestyle='--', label='X Threshold')
plt.axhline(y_threshold, color='red', linestyle='--', label='Y Threshold')
plt.scatter(x=prism_O00255["cavity_score_ml_02_00"], y=prism_O00255["esm1b_masked_marginals_01_00"], c=z, marker='^', cmap = 'viridis', label = ' Scattetplot')
plt.colorbar(label='Gradient')

plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ('O00255 = MeninO00255 = Menin', loc='right', y=-0.01, fontsize = 10)
plt.show()

# %%
# !pip install scipy
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

from pylab import *
from scipy.optimize import curve_fit

#ddG
y,x,_=plt.hist(prism_O00255["cavity_score_ml_02_00"],100,alpha=.3,label='data')

x=(x[1:]+x[:-1])/2 # for len(x)==len(y)

def gauss(x,mu,sigma,A):
    return A*exp(-(x-mu)**2/2/sigma**2)

def bimodal(x,mu1,sigma1,A1,mu2,sigma2,A2):
    return gauss(x,mu1,sigma1,A1)+gauss(x,mu2,sigma2,A2)

params,cov=curve_fit(bimodal,x,y)
sigma=sqrt(diag(cov))
plot(x,bimodal(x,*params),color='red',lw=3,label='model')
plt.xlabel('ddG')
legend()
print(params,'\n',sigma) 

#threshold by eye would be 2

# %%
prism_O15305= pd.read_csv('/Users/nikola/Desktop/MERGED NEW/prism_O15305.txt', delim_whitespace=True, comment = '#')

prism_O15305 = prism_O15305.loc[~(prism_O15305['variant'].str.endswith('=')|prism_O15305['variant'].str.endswith('~')|prism_O00255['variant'].str.endswith('*'))]

sns.jointplot(x=prism_O15305["cavity_score_ml_02_00"], y=prism_O15305["esm1b_masked_marginals_01_00"], kind='scatter',marginal_ticks=True)
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ('O15305 = Phosphomannomutase 2', loc='right', y=-0.01, fontsize = 10)
plt.show()
  
valid_values = ['pathogenic', 'benign']
filtered_df1 = prism_O15305[prism_O15305["clinvar_Clinvar_signifiance_06_00"].isin(valid_values)]
filtered_df1 

sns.jointplot(x=filtered_df1 ["cavity_score_ml_02_00"], y=filtered_df1["esm1b_masked_marginals_01_00"], hue=filtered_df1["clinvar_Clinvar_signifiance_06_00"], kind='scatter',marginal_ticks=True,palette={'pathogenic': '#d7191c', 'benign': '#008000'})
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ('O15305 = Phosphomannomutase 2', loc='right', y=-0.01, fontsize = 10)
plt.show()   

sns.jointplot(x=filtered_df["cavity_score_ml_02_00"], y=filtered_df["esm1b_masked_marginals_01_00"], hue= filtered_df["clinvar_Clinvar_signifiance_06_00"], kind='scatter',marginal_ticks=True, palette={'pathogenic': '#d7191c', 'benign': '#008000'})
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.legend()
plt.title ('O00255 = Menin', loc='right', y=-0.01, fontsize = 10)
 
z =prism_O00255["maxdelta_01"]
x_threshold = 2
y_threshold = -3
plt.axvline(x_threshold, color='red', linestyle='--', label='X Threshold')
plt.axhline(y_threshold, color='red', linestyle='--', label='Y Threshold')
plt.scatter(x=prism_O00255["cavity_score_ml_02_00"], y=prism_O00255["esm1b_masked_marginals_01_00"], c=z, marker='^', cmap = 'viridis', label = ' Scattetplot')
plt.colorbar(label='Gradient')

plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ('O00255 = MeninO00255 = Menin', loc='right', y=-0.01, fontsize = 10)
plt.show()

# %%
#ddG
y,x,_=plt.hist(prism_O15305["cavity_score_ml_02_00"],100,alpha=.3,label='data')

x=(x[1:]+x[:-1])/2 # for len(x)==len(y)

def gauss(x,mu,sigma,A):
    return A*exp(-(x-mu)**2/2/sigma**2)

def bimodal(x,mu1,sigma1,A1,mu2,sigma2,A2):
    return gauss(x,mu1,sigma1,A1)+gauss(x,mu2,sigma2,A2)

params,cov=curve_fit(bimodal,x,y)
sigma=sqrt(diag(cov))
plot(x,bimodal(x,*params),color='red',lw=3,label='model')
plt.xlabel('ddG')
legend()
print(params,'\n',sigma) 
#threshold by eye would be 1

# %%
#ddE
y,x,_=plt.hist(prism_O15305["esm1b_masked_marginals_01_00"],100,alpha=.3,label='data')

x=(x[1:]+x[:-1])/2 # for len(x)==len(y)

def gauss(x,mu,sigma,A):
    return A*exp(-(x-mu)**2/2/sigma**2)

def bimodal(x,mu1,sigma1,A1,mu2,sigma2,A2):
    return gauss(x,mu1,sigma1,A1)+gauss(x,mu2,sigma2,A2)

params,cov=curve_fit(bimodal,x,y)
sigma=sqrt(diag(cov))
plot(x,bimodal(x,*params),color='red',lw=3,label='model')
legend()
print(params,'\n',sigma) 
#threshold by eye would be -7

# %%
prism_P00441= pd.read_csv('/Users/nikola/Desktop/MERGED NEW/prism_P00441.txt', delim_whitespace=True, comment = '#')
prism_P00441.head()

prism_P00441 = prism_P00441.loc[~(prism_P00441['variant'].str.endswith('=')|prism_P00441['variant'].str.endswith('~')|prism_P00441['variant'].str.endswith('*'))]

sns.jointplot(x=prism_P00441["cavity_score_ml_02_00"], y=prism_P00441["esm1b_masked_marginals_01_00"], kind='scatter',marginal_ticks=True)
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("P00441 = Superoxide dismutase ", loc='right', y=-0.01, fontsize = 10)
plt.show()

valid_values = ['pathogenic', 'benign']
filtered_df2 = prism_P00441[prism_P00441["clinvar_Clinvar_signifiance_06_00"].isin(valid_values)]
filtered_df2 

sns.jointplot(x=filtered_df2["cavity_score_ml_02_00"], y=filtered_df2["esm1b_masked_marginals_01_00"], hue=filtered_df2["clinvar_Clinvar_signifiance_06_00"], kind='scatter',marginal_ticks=True, palette={'pathogenic': '#d7191c', 'benign': '#008000'})
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("P00441 = Superoxide dismutase ", loc='right', y=-0.01, fontsize = 10)
plt.show()

# %%
#ddG
y,x,_=plt.hist(prism_P00441["cavity_score_ml_02_00"],100,alpha=.3,label='data')

x=(x[1:]+x[:-1])/2 # for len(x)==len(y)

def gauss(x,mu,sigma,A):
    return A*exp(-(x-mu)**2/2/sigma**2)

def bimodal(x,mu1,sigma1,A1,mu2,sigma2,A2):
    return gauss(x,mu1,sigma1,A1)+gauss(x,mu2,sigma2,A2)

params,cov=curve_fit(bimodal,x,y)
sigma=sqrt(diag(cov))
plot(x,bimodal(x,*params),color='red',lw=3,label='model')
plt.xlabel('ddG')
legend()
print(params,'\n',sigma)

# %%
#ddE
y,x,_=plt.hist(prism_P00441["esm1b_masked_marginals_01_00"],100,alpha=.3,label='data')

x=(x[1:]+x[:-1])/2 # for len(x)==len(y)

def gauss(x,mu,sigma,A):
    return A*exp(-(x-mu)**2/2/sigma**2)

def bimodal(x,mu1,sigma1,A1,mu2,sigma2,A2):
    return gauss(x,mu1,sigma1,A1)+gauss(x,mu2,sigma2,A2)

params,cov=curve_fit(bimodal,x,y)
sigma=sqrt(diag(cov))
plot(x,bimodal(x,*params),color='red',lw=3,label='model')
legend()
print(params,'\n',sigma)

# %%
#ddG
y,x,_=plt.hist(prism_P00441["cavity_score_ml_02_00"],100,alpha=.3,label='data')

x=(x[1:]+x[:-1])/2 # for len(x)==len(y)

def gauss(x,mu,sigma,A):
    return A*exp(-(x-mu)**2/2/sigma**2)

def bimodal(x,mu1,sigma1,A1,mu2,sigma2,A2):
    return gauss(x,mu1,sigma1,A1)+gauss(x,mu2,sigma2,A2)

params,cov=curve_fit(bimodal,x,y)
sigma=sqrt(diag(cov))
plot(x,bimodal(x,*params),color='red',lw=3,label='model')
legend()
print(params,'\n',sigma)

# %%
prism_P00480= pd.read_csv('/Users/nikola/Desktop/MERGED NEW/prism_P00480.txt', delim_whitespace=True, comment = '#')
prism_P00480 = prism_P00480.loc[~(prism_P00480['variant'].str.endswith('=')|prism_P00480['variant'].str.endswith('~')|prism_P00480['variant'].str.endswith('*'))]

sns.jointplot(x=prism_P00480["cavity_score_ml_02_00"], y=prism_P00480["esm1b_masked_marginals_01_00"], kind='scatter',marginal_ticks=True)
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("P00480 = Ornithine transcarbamylase", loc='right', y=-0.01, fontsize = 10)
plt.show()

valid_values = ['pathogenic', 'benign']
filtered_df3 = prism_P00480[prism_P00480["clinvar_Clinvar_signifiance_06_00"].isin(valid_values)]
filtered_df3 

sns.jointplot(x=filtered_df3["cavity_score_ml_02_00"], y=filtered_df3["esm1b_masked_marginals_01_00"], hue=filtered_df3["clinvar_Clinvar_signifiance_06_00"], kind='scatter',marginal_ticks=True, palette={'pathogenic': '#d7191c', 'benign': '#008000'})
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("P00480 = Ornithine transcarbamylase", loc='right', y=-0.01, fontsize = 10)
plt.show()

# %%
#ddG
y,x,_=plt.hist(prism_P00480["cavity_score_ml_02_00"],100,alpha=.3,label='data')

x=(x[1:]+x[:-1])/2 # for len(x)==len(y)

def gauss(x,mu,sigma,A):
    return A*exp(-(x-mu)**2/2/sigma**2)

def bimodal(x,mu1,sigma1,A1,mu2,sigma2,A2):
    return gauss(x,mu1,sigma1,A1)+gauss(x,mu2,sigma2,A2)

params,cov=curve_fit(bimodal,x,y)
sigma=sqrt(diag(cov))
plot(x,bimodal(x,*params),color='red',lw=3,label='model')
legend()
print(params,'\n',sigma)

# %%
prism_P02766= pd.read_csv('/Users/nikola/Desktop/MERGED NEW/prism_P02766.txt', delim_whitespace=True, comment = '#')
prism_P02766 = prism_P02766.loc[~(prism_P02766['variant'].str.endswith('=')|prism_P02766['variant'].str.endswith('~')|prism_P02766['variant'].str.endswith('*'))]

sns.jointplot(x=prism_P02766["cavity_score_ml_02_00"], y=prism_P02766["esm1b_masked_marginals_01_00"], kind='scatter',marginal_ticks=True)
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("P02766 = Transthyretin", loc='right', y=-0.01, fontsize = 10)
plt.show()

valid_values = ['pathogenic', 'benign']
filtered_df4 = prism_P02766[prism_P02766["clinvar_Clinvar_signifiance_06_00"].isin(valid_values)]
filtered_df4

sns.jointplot(x=filtered_df4["cavity_score_ml_02_00"], y=filtered_df4["esm1b_masked_marginals_01_00"], hue=filtered_df4["clinvar_Clinvar_signifiance_06_00"], kind='scatter',marginal_ticks=True,palette={'pathogenic': '#d7191c', 'benign': '#008000'})
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("P02766 = Transthyretin", loc='right', y=-0.01, fontsize = 10)
plt.show()

# %%
#ddG
y,x,_=plt.hist(prism_P02766["cavity_score_ml_02_00"],100,alpha=.3,label='data')

x=(x[1:]+x[:-1])/2 # for len(x)==len(y)

def gauss(x,mu,sigma,A):
    return A*exp(-(x-mu)**2/2/sigma**2)

def bimodal(x,mu1,sigma1,A1,mu2,sigma2,A2):
    return gauss(x,mu1,sigma1,A1)+gauss(x,mu2,sigma2,A2)

params,cov=curve_fit(bimodal,x,y)
sigma=sqrt(diag(cov))
plot(x,bimodal(x,*params),color='red',lw=3,label='model')
legend()
print(params,'\n',sigma)

# %%
prism_P04637= pd.read_csv('/Users/nikola/Desktop/MERGED NEW/prism_P04637.txt', delim_whitespace=True, comment = '#')
prism_P04637 = prism_P04637.loc[~(prism_P04637['variant'].str.endswith('=')|prism_P04637['variant'].str.endswith('~')|prism_P04637['variant'].str.endswith('*'))]

sns.jointplot(x=prism_P04637["cavity_score_ml_02_00"], y=prism_P04637["esm1b_masked_marginals_01_00"], kind='scatter',marginal_ticks=True)
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("P04637 = Cellular tumor antigen p53", loc='right', y=-0.01, fontsize = 10)
plt.show()

valid_values = ['pathogenic', 'benign']
filtered_df5 = prism_P04637[prism_P04637["clinvar_Clinvar_signifiance_06_00"].isin(valid_values)]
filtered_df5

sns.jointplot(x=filtered_df5["cavity_score_ml_02_00"], y=filtered_df5["esm1b_masked_marginals_01_00"],hue=filtered_df5["clinvar_Clinvar_signifiance_06_00"], kind='scatter',marginal_ticks=True,palette={'pathogenic': '#d7191c', 'benign': '#008000'})
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("P04637 = Cellular tumor antigen p53", loc='right', y=-0.01, fontsize = 10)
plt.show()

# %%
#ddG
y,x,_=plt.hist(prism_P04637["cavity_score_ml_02_00"],100,alpha=.3,label='data')

x=(x[1:]+x[:-1])/2 # for len(x)==len(y)

def gauss(x,mu,sigma,A):
    return A*exp(-(x-mu)**2/2/sigma**2)

def bimodal(x,mu1,sigma1,A1,mu2,sigma2,A2):
    return gauss(x,mu1,sigma1,A1)+gauss(x,mu2,sigma2,A2)

params,cov=curve_fit(bimodal,x,y)
sigma=sqrt(diag(cov))
plot(x,bimodal(x,*params),color='red',lw=3,label='model')
legend()
print(params,'\n',sigma)

# %%
prism_P08246= pd.read_csv('/Users/nikola/Desktop/MERGED NEW/prism_P08246.txt', delim_whitespace=True, comment = '#')
prism_P08246 = prism_P08246.loc[~(prism_P08246['variant'].str.endswith('=')|prism_P08246['variant'].str.endswith('~')|prism_P08246['variant'].str.endswith('*'))]

sns.jointplot(x=prism_P08246["cavity_score_ml_02_00"], y=prism_P08246["esm1b_masked_marginals_01_00"], kind='scatter',marginal_ticks=True)
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("P08246 = Neutrophil elastase", loc='right', y=-0.01, fontsize = 10)
plt.show()

valid_values = ['pathogenic', 'benign']
filtered_df6 = prism_P08246[prism_P08246["clinvar_Clinvar_signifiance_06_00"].isin(valid_values)]
filtered_df6

sns.jointplot(x=filtered_df6["cavity_score_ml_02_00"], y=filtered_df6["esm1b_masked_marginals_01_00"],hue=filtered_df6["clinvar_Clinvar_signifiance_06_00"], kind='scatter',marginal_ticks=True, palette={'pathogenic': '#d7191c', 'benign': '#008000'})
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("P08246 = Neutrophil elastase", loc='right', y=-0.01, fontsize = 10)
plt.show()

# %%
#ddG
y,x,_=plt.hist(prism_P08246["cavity_score_ml_02_00"],100,alpha=.3,label='data')

x=(x[1:]+x[:-1])/2 # for len(x)==len(y)

def gauss(x,mu,sigma,A):
    return A*exp(-(x-mu)**2/2/sigma**2)

def bimodal(x,mu1,sigma1,A1,mu2,sigma2,A2):
    return gauss(x,mu1,sigma1,A1)+gauss(x,mu2,sigma2,A2)

params,cov=curve_fit(bimodal,x,y)
sigma=sqrt(diag(cov))
plot(x,bimodal(x,*params),color='red',lw=3,label='model')
legend()
print(params,'\n',sigma)

# %%
prism_P30566= pd.read_csv('/Users/nikola/Desktop/MERGED NEW/prism_P30566.txt', delim_whitespace=True, comment = '#')
prism_P30566 = prism_P30566.loc[~(prism_P30566['variant'].str.endswith('=')|prism_P30566['variant'].str.endswith('~')|prism_P30566['variant'].str.endswith('*'))]

sns.jointplot(x=prism_P30566["cavity_score_ml_02_00"], y=prism_P30566["esm1b_masked_marginals_01_00"], kind='scatter',marginal_ticks=True)
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("P30566 = Adenylosuccinate lyase", loc='right', y=-0.01, fontsize = 10)
plt.show()


valid_values = ['pathogenic', 'benign']
filtered_df7 = prism_P30566[prism_P30566["clinvar_Clinvar_signifiance_06_00"].isin(valid_values)]
filtered_df7

sns.jointplot(x=filtered_df7["cavity_score_ml_02_00"], y=filtered_df7["esm1b_masked_marginals_01_00"],hue=filtered_df7["clinvar_Clinvar_signifiance_06_00"], kind='scatter',marginal_ticks=True, palette={'pathogenic': '#d7191c', 'benign': '#008000'})
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("P30566 = Adenylosuccinate lyase", loc='right', y=-0.01, fontsize = 10)
plt.show()

# %%
#ddG
y,x,_=plt.hist(prism_P30566["cavity_score_ml_02_00"],100,alpha=.3,label='data')

x=(x[1:]+x[:-1])/2 # for len(x)==len(y)

def gauss(x,mu,sigma,A):
    return A*exp(-(x-mu)**2/2/sigma**2)

def bimodal(x,mu1,sigma1,A1,mu2,sigma2,A2):
    return gauss(x,mu1,sigma1,A1)+gauss(x,mu2,sigma2,A2)

params,cov=curve_fit(bimodal,x,y)
sigma=sqrt(diag(cov))
plot(x,bimodal(x,*params),color='red',lw=3,label='model')
legend()
print(params,'\n',sigma)

# %%
prism_P35520= pd.read_csv('/Users/nikola/Desktop/MERGED NEW/prism_P35520.txt', delim_whitespace=True, comment = '#')
prism_P35520 = prism_P35520.loc[~(prism_P35520['variant'].str.endswith('=')|prism_P35520['variant'].str.endswith('~')|prism_P35520['variant'].str.endswith('*'))]

sns.jointplot(x=prism_P35520["cavity_score_ml_02_00"], y=prism_P35520["esm1b_masked_marginals_01_00"], kind='scatter',marginal_ticks=True)
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("P35520 = Cystathionine beta-synthase", loc='right', y=-0.01, fontsize = 10)
plt.show()


valid_values = ['pathogenic', 'benign']
filtered_df8 = prism_P35520[prism_P35520["clinvar_Clinvar_signifiance_06_00"].isin(valid_values)]
filtered_df8

sns.jointplot(x=filtered_df8["cavity_score_ml_02_00"], y=filtered_df8["esm1b_masked_marginals_01_00"],hue=filtered_df8["clinvar_Clinvar_signifiance_06_00"], kind='scatter',marginal_ticks=True, palette={'pathogenic': '#d7191c', 'benign': '#008000'})
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("P35520 = Cystathionine beta-synthase", loc='right', y=-0.01, fontsize = 10)
plt.show()

# %%
#ddG
y,x,_=plt.hist(prism_P35520["cavity_score_ml_02_00"],100,alpha=.3,label='data')

x=(x[1:]+x[:-1])/2 # for len(x)==len(y)

def gauss(x,mu,sigma,A):
    return A*exp(-(x-mu)**2/2/sigma**2)

def bimodal(x,mu1,sigma1,A1,mu2,sigma2,A2):
    return gauss(x,mu1,sigma1,A1)+gauss(x,mu2,sigma2,A2)

params,cov=curve_fit(bimodal,x,y)
sigma=sqrt(diag(cov))
plot(x,bimodal(x,*params),color='red',lw=3,label='model')
legend()
print(params,'\n',sigma)

# %%
prism_P35557= pd.read_csv('/Users/nikola/Desktop/MERGED NEW/prism_P35557.txt', delim_whitespace=True, comment = '#')
prism_P35557 = prism_P35557.loc[~(prism_P35557['variant'].str.endswith('=')|prism_P35557['variant'].str.endswith('~')|prism_P35557['variant'].str.endswith('*'))]

sns.jointplot(x=prism_P35557["cavity_score_ml_02_00"], y=prism_P35557["esm1b_masked_marginals_01_00"], kind='scatter',marginal_ticks=True)
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("P35557 = Hexokinase-4", loc='right', y=-0.01, fontsize = 10)
plt.show()

valid_values = ['pathogenic', 'benign']
filtered_df9 = prism_P35557[prism_P35557["clinvar_Clinvar_signifiance_06_00"].isin(valid_values)]
filtered_df9

sns.jointplot(x=filtered_df9["cavity_score_ml_02_00"], y=filtered_df9["esm1b_masked_marginals_01_00"],hue=filtered_df9["clinvar_Clinvar_signifiance_06_00"], kind='scatter',marginal_ticks=True, palette={'pathogenic': '#d7191c', 'benign': '#008000'})
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("P35557 = Hexokinase-4", loc='right', y=-0.01, fontsize = 10)
plt.show()

# %%
#ddG
y,x,_=plt.hist(prism_P35557["cavity_score_ml_02_00"],100,alpha=.3,label='data')

x=(x[1:]+x[:-1])/2 # for len(x)==len(y)

def gauss(x,mu,sigma,A):
    return A*exp(-(x-mu)**2/2/sigma**2)

def bimodal(x,mu1,sigma1,A1,mu2,sigma2,A2):
    return gauss(x,mu1,sigma1,A1)+gauss(x,mu2,sigma2,A2)

params,cov=curve_fit(bimodal,x,y)
sigma=sqrt(diag(cov))
plot(x,bimodal(x,*params),color='red',lw=3,label='model')
legend()
print(params,'\n',sigma)

# %%
prism_P52701= pd.read_csv('/Users/nikola/Desktop/MERGED NEW/prism_P52701.txt', delim_whitespace=True, comment = '#')
prism_P52701 = prism_P52701.loc[~(prism_P52701['variant'].str.endswith('=')|prism_P52701['variant'].str.endswith('~')|prism_P52701['variant'].str.endswith('*'))]

sns.jointplot(x=prism_P52701["cavity_score_ml_02_00"], y=prism_P52701["esm1b_masked_marginals_01_00"], kind='scatter',marginal_ticks=True)
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("P52701 = DNA mismatch repair protein Msh6", loc='right', y=-0.01, fontsize = 10)
plt.show()

valid_values = ['pathogenic', 'benign']
filtered_df10 = prism_P52701[prism_P52701["clinvar_Clinvar_signifiance_06_00"].isin(valid_values)]
filtered_df10

sns.jointplot(x=filtered_df10["cavity_score_ml_02_00"], y=filtered_df10["esm1b_masked_marginals_01_00"],hue=filtered_df10["clinvar_Clinvar_signifiance_06_00"], kind='scatter',marginal_ticks=True, palette={'pathogenic': '#d7191c', 'benign': '#008000'})
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("P52701 = DNA mismatch repair protein Msh6", loc='right', y=-0.01, fontsize = 10)
plt.show()

# %%
#ddG
y,x,_=plt.hist(prism_P52701["cavity_score_ml_02_00"],100,alpha=.3,label='data')

x=(x[1:]+x[:-1])/2 # for len(x)==len(y)

def gauss(x,mu,sigma,A):
    return A*exp(-(x-mu)**2/2/sigma**2)

def bimodal(x,mu1,sigma1,A1,mu2,sigma2,A2):
    return gauss(x,mu1,sigma1,A1)+gauss(x,mu2,sigma2,A2)

params,cov=curve_fit(bimodal,x,y)
sigma=sqrt(diag(cov))
plot(x,bimodal(x,*params),color='red',lw=3,label='model')
legend()
print(params,'\n',sigma)

# %%
prism_Q16518= pd.read_csv('/Users/nikola/Desktop/MERGED NEW/prism_Q16518.txt', delim_whitespace=True, comment = '#')
prism_Q16518 = prism_Q16518.loc[~(prism_Q16518['variant'].str.endswith('=')|prism_Q16518['variant'].str.endswith('~')|prism_Q16518['variant'].str.endswith('*'))]

sns.jointplot(x=prism_Q16518["cavity_score_ml_02_00"], y=prism_Q16518["esm1b_masked_marginals_01_00"], kind='scatter',marginal_ticks=True)
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("Q16518 = Retinoid isomerohydrolase", loc='right', y=-0.01, fontsize = 10)
plt.show()

valid_values = ['pathogenic', 'benign']
filtered_df11 = prism_Q16518[prism_Q16518["clinvar_Clinvar_signifiance_06_00"].isin(valid_values)]
filtered_df11

sns.jointplot(x=filtered_df11["cavity_score_ml_02_00"], y=filtered_df11["esm1b_masked_marginals_01_00"],hue=filtered_df11["clinvar_Clinvar_signifiance_06_00"], kind='scatter',marginal_ticks=True, palette={'pathogenic': '#d7191c', 'benign': '#008000'})
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("Q16518 = Retinoid isomerohydrolase", loc='right', y=-0.01, fontsize = 10)
plt.show()

# %%
#ddG
y,x,_=plt.hist(prism_Q16518["cavity_score_ml_02_00"],100,alpha=.3,label='data')

x=(x[1:]+x[:-1])/2 # for len(x)==len(y)

def gauss(x,mu,sigma,A):
    return A*exp(-(x-mu)**2/2/sigma**2)

def bimodal(x,mu1,sigma1,A1,mu2,sigma2,A2):
    return gauss(x,mu1,sigma1,A1)+gauss(x,mu2,sigma2,A2)

params,cov=curve_fit(bimodal,x,y)
sigma=sqrt(diag(cov))
plot(x,bimodal(x,*params),color='red',lw=3,label='model')
legend()

# %%
prism_P43246= pd.read_csv('/Users/nikola/Desktop/MERGED NEW/prism_P43246.txt', delim_whitespace=True, comment = '#')
prism_P43246 = prism_P43246.loc[~(prism_P43246['variant'].str.endswith('=')|prism_P43246['variant'].str.endswith('~')|prism_P43246['variant'].str.endswith('*'))]

sns.jointplot(x=prism_P43246["cavity_score_ml_02_00"], y=prism_P43246["esm1b_masked_marginals_01_00"], kind='scatter',marginal_ticks=True)
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("P43246 = DNA mismatch repair protein Msh2", loc='right', y=-0.01, fontsize = 10)
plt.show()

valid_values = ['pathogenic', 'benign']
filtered_df12 = prism_P43246[prism_P43246["clinvar_Clinvar_signifiance_06_00"].isin(valid_values)]
filtered_df12

sns.jointplot(x=filtered_df12["cavity_score_ml_02_00"], y=filtered_df12["esm1b_masked_marginals_01_00"],hue=filtered_df12["clinvar_Clinvar_signifiance_06_00"], kind='scatter',marginal_ticks=True, palette={'pathogenic': '#d7191c', 'benign': '#008000'})
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("P43246 = DNA mismatch repair protein Msh2", loc='right', y=-0.01, fontsize = 10)
plt.show()

# %%
#ddG
y,x,_=plt.hist(prism_P43246["cavity_score_ml_02_00"],100,alpha=.3,label='data')

x=(x[1:]+x[:-1])/2 # for len(x)==len(y)

def gauss(x,mu,sigma,A):
    return A*exp(-(x-mu)**2/2/sigma**2)

def bimodal(x,mu1,sigma1,A1,mu2,sigma2,A2):
    return gauss(x,mu1,sigma1,A1)+gauss(x,mu2,sigma2,A2)

params,cov=curve_fit(bimodal,x,y)
sigma=sqrt(diag(cov))
plot(x,bimodal(x,*params),color='red',lw=3,label='model')
legend()

# %%
prism_P45381= pd.read_csv('/Users/nikola/Desktop/MERGED NEW/prism_P45381.txt', delim_whitespace=True, comment = '#')
prism_P45381 = prism_P45381.loc[~(prism_P45381['variant'].str.endswith('=')|prism_P45381['variant'].str.endswith('~')|prism_P45381['variant'].str.endswith('*'))]

sns.jointplot(x=prism_P45381["cavity_score_ml_02_00"], y=prism_P45381["esm1b_masked_marginals_01_00"], kind='scatter',marginal_ticks=True)
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("P45381 = Aspartoacylase", loc='right', y=-0.01, fontsize = 10)
plt.show()

valid_values = ['pathogenic', 'benign']
filtered_df13 = prism_P45381[prism_P45381["clinvar_Clinvar_signifiance_06_00"].isin(valid_values)]
filtered_df13


sns.jointplot(x=filtered_df13["cavity_score_ml_02_00"], y=filtered_df13["esm1b_masked_marginals_01_00"],hue=filtered_df13["clinvar_Clinvar_signifiance_06_00"], kind='scatter',marginal_ticks=True, palette={'pathogenic': '#d7191c', 'benign': '#008000'})
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("P45381 = Aspartoacylase", loc='right', y=-0.01, fontsize = 10)
plt.show()

# %%
#ddG
y,x,_=plt.hist(prism_P45381["cavity_score_ml_02_00"],100,alpha=.3,label='data')

x=(x[1:]+x[:-1])/2 # for len(x)==len(y)

def gauss(x,mu,sigma,A):
    return A*exp(-(x-mu)**2/2/sigma**2)

def bimodal(x,mu1,sigma1,A1,mu2,sigma2,A2):
    return gauss(x,mu1,sigma1,A1)+gauss(x,mu2,sigma2,A2)

params,cov=curve_fit(bimodal,x,y)
sigma=sqrt(diag(cov))
plot(x,bimodal(x,*params),color='red',lw=3,label='model')
legend()

# %%
prism_P40692= pd.read_csv('/Users/nikola/Desktop/MERGED NEW/prism_P40692.txt', delim_whitespace=True, comment = '#')
prism_P40692 = prism_P40692.loc[~(prism_P40692['variant'].str.endswith('=')|prism_P40692['variant'].str.endswith('~')|prism_P40692['variant'].str.endswith('*'))]

sns.jointplot(x=prism_P40692["cavity_score_ml_02_00"], y=prism_P40692["esm1b_masked_marginals_01_00"], kind='scatter',marginal_ticks=True)
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("P40692 = DNA mismatch repair protein Mlh1", loc='right', y=-0.01, fontsize = 10)
plt.show()

valid_values = ['pathogenic', 'benign']
filtered_df14 = prism_P40692[prism_P40692["clinvar_Clinvar_signifiance_06_00"].isin(valid_values)]
filtered_df14

sns.jointplot(x=filtered_df14["cavity_score_ml_02_00"], y=filtered_df14["esm1b_masked_marginals_01_00"],hue=filtered_df14["clinvar_Clinvar_signifiance_06_00"], kind='scatter',marginal_ticks=True, palette={'pathogenic': '#d7191c', 'benign': '#008000'})
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("P40692 = DNA mismatch repair protein Mlh1", loc='right', y=-0.01, fontsize = 10)
plt.show()

# %%
#ddG
y,x,_=plt.hist(prism_P40692["cavity_score_ml_02_00"],100,alpha=.3,label='data')

x=(x[1:]+x[:-1])/2 # for len(x)==len(y)

def gauss(x,mu,sigma,A):
    return A*exp(-(x-mu)**2/2/sigma**2)

def bimodal(x,mu1,sigma1,A1,mu2,sigma2,A2):
    return gauss(x,mu1,sigma1,A1)+gauss(x,mu2,sigma2,A2)

params,cov=curve_fit(bimodal,x,y)
sigma=sqrt(diag(cov))
plot(x,bimodal(x,*params),color='red',lw=3,label='model')
legend()

# %%
prism_P40337= pd.read_csv('/Users/nikola/Desktop/MERGED NEW/prism_P40337.txt', delim_whitespace=True, comment = '#')
prism_P40337 = prism_P40337.loc[~(prism_P40337['variant'].str.endswith('=')|prism_P40337['variant'].str.endswith('~')|prism_P40337['variant'].str.endswith('*'))]


sns.jointplot(x=prism_P40337["cavity_score_ml_02_00"], y=prism_P40337["esm1b_masked_marginals_01_00"], kind='scatter',marginal_ticks=True)
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("P40337 = Von Hippel-Lindau disease tumor suppressor", loc='right', y=-0.01, fontsize = 10)
plt.show()

valid_values = ['pathogenic', 'benign']
filtered_df15 = prism_P40337[prism_P40337["clinvar_Clinvar_signifiance_06_00"].isin(valid_values)]
filtered_df15

sns.jointplot(x=filtered_df15["cavity_score_ml_02_00"], y=filtered_df15["esm1b_masked_marginals_01_00"],hue=filtered_df15["clinvar_Clinvar_signifiance_06_00"], kind='scatter',marginal_ticks=True, palette={'pathogenic': '#d7191c', 'benign': '#008000'})
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")
plt.title ("P40337 = Von Hippel-Lindau disease tumor suppressor", loc='right', y=-0.01, fontsize = 10)
plt.show()

# %%
#ddG
y,x,_=plt.hist(prism_P40337["cavity_score_ml_02_00"],100,alpha=.3,label='data')

x=(x[1:]+x[:-1])/2 # for len(x)==len(y)

def gauss(x,mu,sigma,A):
    return A*exp(-(x-mu)**2/2/sigma**2)

def bimodal(x,mu1,sigma1,A1,mu2,sigma2,A2):
    return gauss(x,mu1,sigma1,A1)+gauss(x,mu2,sigma2,A2)

params,cov=curve_fit(bimodal,x,y)
sigma=sqrt(diag(cov))
plot(x,bimodal(x,*params),color='red',lw=3,label='model')
legend()

# %%
#1. scatter plot 
x1=prism_O00255["cavity_score_ml_02_00"]
y1=prism_O00255["esm1b_masked_marginals_01_00"]
plt.scatter(x1, y1) 
plt.xlabel("ddG")
plt.ylabel("ddE(ESM1B)")

#2. scatter plot 
x2=prism_O15305["cavity_score_ml_02_00"]
y2=prism_O15305["esm1b_masked_marginals_01_00"]
plt.scatter(x2, y2)

#3. scatter plot 
x3=prism_P00441["cavity_score_ml_02_00"]
y3=prism_P00441["esm1b_masked_marginals_01_00"]
plt.scatter(x3, y3)

#4. scatter plot 
x4=prism_P00480["cavity_score_ml_02_00"]
y4=prism_P00480["esm1b_masked_marginals_01_00"]
plt.scatter(x4, y4)

#5. scatter plot 
x5=prism_P02766["cavity_score_ml_02_00"]
y5=prism_P02766["esm1b_masked_marginals_01_00"]
plt.scatter(x5, y5)

#6. scatter plot 
x6=prism_P04637["cavity_score_ml_02_00"]
y6=prism_P04637["esm1b_masked_marginals_01_00"]
plt.scatter(x6, y6)

#7. scatter plot 
x7=prism_P08246["cavity_score_ml_02_00"]
y7=prism_P08246["esm1b_masked_marginals_01_00"]
plt.scatter(x7, y7)

#8. scatter plot 
x8=prism_P30566["cavity_score_ml_02_00"]
y8=prism_P30566["esm1b_masked_marginals_01_00"]
plt.scatter(x8, y8)

#9. scatter plot 
x9=prism_P35520["cavity_score_ml_02_00"]
y9=prism_P35520["esm1b_masked_marginals_01_00"]
plt.scatter(x9, y9)

#10. scatter plot 
x10=prism_P35557["cavity_score_ml_02_00"]
y10=prism_P35557["esm1b_masked_marginals_01_00"]
plt.scatter(x10, y10)

#11. scatter plot 
x11=prism_P52701["cavity_score_ml_02_00"]
y11=prism_P52701["esm1b_masked_marginals_01_00"]
plt.scatter(x11, y11)

#12. scatter plot 
x12=prism_Q16518["cavity_score_ml_02_00"]
y12=prism_Q16518["esm1b_masked_marginals_01_00"]
plt.scatter(x12, y12)

#13. scatter plot 
x13=prism_P43246["cavity_score_ml_02_00"]
y13=prism_P43246["esm1b_masked_marginals_01_00"]
plt.scatter(x13, y13)

#14. scatter plot 
x14=prism_P45381["cavity_score_ml_02_00"]
y14=prism_P45381["esm1b_masked_marginals_01_00"]
plt.scatter(x14, y14)

#15. scatter plot 
x15=prism_P40692["cavity_score_ml_02_00"]
y15=prism_P40692["esm1b_masked_marginals_01_00"]
plt.scatter(x15, y15)

#16. scatter plot 
x16=prism_P40337["cavity_score_ml_02_00"]
y16=prism_P40337["esm1b_masked_marginals_01_00"]
plt.scatter(x16, y16)
plt.title('Overlay of the esm1b-distributions')
plt.show()
